# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Tarefa II
#
# Neste projeto, estamos construindo um credit scoring para cartão de crédito, em um desenho amostral com 15 safras, e utilizando 12 meses de performance.
#
# Carregue a base de dados ```credit_scoring.ftr```.

# %%
import pandas as pd
import numpy as np
from scipy.stats import t
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn import metrics
from scipy.stats import ks_2samp
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from pycaret.classification import *
import pickle

# %%
df = pd.read_feather('credit_scoring.ftr')
df.head()
# Out:
#     data_ref  index sexo posse_de_veiculo posse_de_imovel  qtd_filhos  \
# 0 2015-01-01   5733    F                N               N           0
# 1 2015-01-01    727    F                S               S           0
# 2 2015-01-01   6374    F                N               N           2
# 3 2015-01-01   9566    F                N               N           0
# 4 2015-01-01   9502    F                S               N           0
#
#     tipo_renda             educacao estado_civil tipo_residencia  idade  \
# 0   Empresário                Médio     Solteiro            Casa     43
# 1  Assalariado                Médio       Casado            Casa     35
# 2  Assalariado                Médio       Casado            Casa     31
# 3  Assalariado                Médio       Casado            Casa     54
# 4  Assalariado  Superior incompleto     Solteiro            Casa     31
#
#    tempo_emprego  qt_pessoas_residencia     renda    mau
# 0       6.873973                    1.0   2515.39  False
# 1       4.526027                    2.0   3180.19  False
# 2       0.243836                    4.0   1582.29  False
# 3      12.772603                    2.0  13721.17  False
# 4       8.432877                    1.0   2891.08  False

# %% [markdown]
# ## Amostragem
#
# Separe os três últimos meses como safras de validação *out of time* (oot).
#
# Variáveis:<br>
# Considere que a variável ```data_ref``` não é uma variável explicativa, é somente uma variável indicadora da safra, e não deve ser utilizada na modelagem. A variávei ```index``` é um identificador do cliente, e também não deve ser utilizada como covariável (variável explicativa). As restantes podem ser utilizadas para prever a inadimplência, incluindo a renda.

# %%
df['ano'] = df['data_ref'].dt.year
df['mes'] = df['data_ref'].dt.month
df['mes_ano'] = df['data_ref'].dt.strftime('%m-%Y')

df_modelo = df[df['ano']==2015]
df_oot = df[df['ano']==2016]

# %% [markdown]
# ## Descritiva básica univariada
#
# - Descreva a base quanto ao número de linhas, número de linhas para cada mês em ```data_ref```.
# - Faça uma descritiva básica univariada de cada variável. Considere as naturezas diferentes: qualitativas e quantitativas.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   data_ref               750000 non-null  datetime64[ns]
#  1   index                  750000 non-null  int64
#  2   sexo                   750000 non-null  object
#  3   posse_de_veiculo       750000 non-null  object
#  4   posse_de_imovel        750000 non-null  object
#  5   qtd_filhos             750000 non-null  int64
#  6   tipo_renda             750000 non-null  object
#  7   educacao               750000 non-null  object
#  8   estado_civil           750000 non-null  object
#  9   tipo_residencia        750000 non-null  object
#  10  idade                  750000 non-null  int64
#  11  tempo_emprego          624043 non-null  float64
#  12  qt_pessoas_residencia  750000 non-null  float64
#  13  renda                  750000 non-null  float64
#  14  mau                    750000 non-null  bool
#  15  ano                    750000 non-null  int64
#  16  mes                    750000 non-null  int64
#  17  mes_ano                750000 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(3), int64(5), object(8)
# memory usage: 98.0+ MB

# %%
df.groupby(['mes'])['mes'].count()
# Out:
# mes
# 1     100000
# 2     100000
# 3     100000
# 4      50000
# 5      50000
# 6      50000
# 7      50000
# 8      50000
# 9      50000
# 10     50000
# 11     50000
# 12     50000
# Name: mes, dtype: int64

# %%
df.describe()
# Out:
#                index     qtd_filhos          idade  tempo_emprego  \
# count  750000.000000  750000.000000  750000.000000  624043.000000
# mean     8319.272793       0.433251      43.804733       7.748574
# std      4809.281774       0.739379      11.229868       6.687455
# min         0.000000       0.000000      22.000000       0.117808
# 25%      4147.000000       0.000000      34.000000       3.049315
# 50%      8324.000000       0.000000      43.000000       6.046575
# 75%     12487.000000       1.000000      53.000000      10.183562
# max     16649.000000      14.000000      68.000000      42.906849
#
#        qt_pessoas_residencia         renda       ano            mes
# count          750000.000000  7.500000e+05  750000.0  750000.000000
# mean                2.212241  2.323854e+04    2015.2       5.600000
# std                 0.903428  7.910601e+04       0.4       3.592587
# min                 1.000000  1.076700e+02    2015.0       1.000000
# 25%                 2.000000  3.467700e+03    2015.0       2.000000
# 50%                 2.000000  7.861820e+03    2015.0       5.000000
# 75%                 3.000000  1.831828e+04    2015.0       9.000000
# max                15.000000  4.083986e+06    2016.0      12.000000

# %%
def IV(variavel, resposta):
    tab = pd.crosstab(variavel, resposta, margins=True, margins_name='total')

    rótulo_evento = tab.columns[0]
    rótulo_nao_evento = tab.columns[1]
 
    tab['pct_evento'] = tab[rótulo_evento]/tab.loc['total',rótulo_evento]
    tab['ep'] = tab[rótulo_evento]/tab.loc['total',rótulo_evento]
    
    tab['pct_nao_evento'] = tab[rótulo_nao_evento]/tab.loc['total',rótulo_nao_evento]
    tab['woe'] = np.log(tab.pct_evento/tab.pct_nao_evento)
    tab['iv_parcial'] = (tab.pct_evento - tab.pct_nao_evento)*tab.woe
    return tab['iv_parcial'].sum()

# %%
metadados = pd.DataFrame(df.dtypes, columns=['dtype'])
metadados['nmissing'] = df.isna().sum()
metadados['valores_unicos'] = df.nunique()
metadados['papel'] = 'covariavel'
metadados.loc['mau','papel'] = 'resposta'
metadados['poder_preditivo'] = '-'

for var in metadados[metadados.papel=='covariavel'].index:
    if  (metadados.loc[var, 'valores_unicos']>6):
        if (var=='mes_ano'): 
            metadados.loc[var, 'IV'] = IV(df[var], df.mau)
        else:
            metadados.loc[var, 'IV'] = IV(pd.qcut(df[var],5,duplicates='drop'), df.mau)
    else: 
        metadados.loc[var, 'IV'] = IV(df[var], df.mau)

metadados.loc['mau','IV'] = '-'
        
for var in metadados[metadados.papel=='covariavel'].index:
    if  (metadados.loc[var, 'IV']<0.02):
        metadados.loc[var, 'poder_preditivo'] = 'Inútil'
    elif (metadados.loc[var, 'IV']<0.1):
        metadados.loc[var, 'poder_preditivo'] = 'Fraco'
    elif (metadados.loc[var, 'IV']<0.3):
        metadados.loc[var, 'poder_preditivo'] = 'Médio'
    elif (metadados.loc[var, 'IV']<0.5):
        metadados.loc[var, 'poder_preditivo'] = 'Forte'
    else: 
        metadados.loc[var, 'poder_preditivo'] = 'Suspeito'
        
metadados
# Out:
#                                 dtype  nmissing  valores_unicos       papel  \
# data_ref               datetime64[ns]         0              15  covariavel
# index                           int64         0           16650  covariavel
# sexo                           object         0               2  covariavel
# posse_de_veiculo               object         0               2  covariavel
# posse_de_imovel                object         0               2  covariavel
# qtd_filhos                      int64         0               8  covariavel
# tipo_renda                     object         0               5  covariavel
# educacao                       object         0               5  covariavel
# estado_civil                   object         0               5  covariavel
# tipo_residencia                object         0               6  covariavel
# idade                           int64         0              47  covariavel
# tempo_emprego                 float64    125957            3004  covariavel
# qt_pessoas_residencia         float64         0               9  covariavel
# renda                         float64         0          142419  covariavel
# mau                              bool         0               2    resposta
# ano                             int64         0               2  covariavel
# mes                             int64         0              12  covariavel
# mes_ano                        object         0              15  covariavel
#
#                       poder_preditivo        IV
# data_ref                        Forte  0.345982
# index                          Inútil  0.002664
# sexo                           Inútil  0.002185
# posse_de_veiculo               Inútil  0.000108
# posse_de_imovel                Inútil  0.009693
# qtd_filhos                     Inútil   0.00003
# tipo_renda                     Inútil   0.00936
# educacao                       Inútil  0.003547
# estado_civil                   Inútil  0.001126
# tipo_residencia                Inútil  0.003045
# idade                          Inútil  0.017968
# tempo_emprego                   Forte   0.35192
# qt_pessoas_residencia          Inútil  0.001346
# renda                        Suspeito  1.068628
# mau                                 -         -
# ano                             Médio  0.184632
# mes                             Forte  0.319654
# mes_ano                         Forte  0.389901

# %% [markdown]
# A partir da análise acima, pelo critério do IV apenas 'tempo_emprego' se mostra uma variável útil.

# %% [markdown]
# ## Descritiva bivariada
#
# Faça uma análise descritiva bivariada de cada variável

# %%
def biv_discreta(var, df):
    df['bom'] = 1-df.mau
    g = df.groupby(var)

    biv = pd.DataFrame({'qt_bom': g['bom'].sum(),
                        'qt_mau': g['mau'].sum(),
                        'mau':g['mau'].mean(), 
                        var: g['mau'].mean().index, 
                        'cont':g[var].count()})
    
    biv['ep'] = (biv.mau*(1-biv.mau)/biv.cont)**.5
    biv['mau_sup'] = biv.mau+t.ppf([0.975], biv.cont-1)*biv.ep
    biv['mau_inf'] = biv.mau+t.ppf([0.025], biv.cont-1)*biv.ep
    
    biv['logit'] = np.log(biv.mau/(1-biv.mau))
    biv['logit_sup'] = np.log(biv.mau_sup/(1-biv.mau_sup))
    biv['logit_inf'] = np.log(biv.mau_inf/(1-biv.mau_inf))

    tx_mau_geral = df.mau.mean()
    woe_geral = np.log(df.mau.mean() / (1 - df.mau.mean()))

    biv['woe'] = biv.logit - woe_geral
    biv['woe_sup'] = biv.logit_sup - woe_geral
    biv['woe_inf'] = biv.logit_inf - woe_geral

    fig, ax = plt.subplots(2,1, figsize=(8,6))
    ax[0].plot(biv[var], biv.woe, ':bo', label='woe')
    ax[0].plot(biv[var], biv.woe_sup, 'o:r', label='limite superior')
    ax[0].plot(biv[var], biv.woe_inf, 'o:r', label='limite inferior')
    
    num_cat = biv.shape[0]
    ax[0].set_xlim([-.3, num_cat-.7])

    ax[0].set_ylabel("Weight of Evidence")
    ax[0].legend(bbox_to_anchor=(.83, 1.17), ncol=3)
    
    ax[0].set_xticks(list(range(num_cat)))
    ax[0].set_xticklabels(biv[var], rotation=15)
    
    ax[1] = biv.cont.plot.bar()
    return biv

# %%
for var in metadados[metadados.dtype=='object'].index:
    biv_discreta(var,df);

# %%
def biv_continua(var, ncat, df):
    df['bom'] = 1-df.mau
    cat_srs, bins = pd.qcut(df[var], ncat, retbins=True, precision=0, duplicates='drop')
    g = df.groupby(cat_srs)

    biv = pd.DataFrame({'qt_bom': g['bom'].sum(),
                        'qt_mau': g['mau'].sum(),
                        'mau':g['mau'].mean(), 
                        var: g[var].mean(), 
                        'cont':g[var].count()})
    
    biv['ep'] = (biv.mau*(1-biv.mau)/biv.cont)**.5
    biv['mau_sup'] = biv.mau+t.ppf([0.975], biv.cont-1)*biv.ep
    biv['mau_inf'] = biv.mau+t.ppf([0.025], biv.cont-1)*biv.ep
    
    biv['logit'] = np.log(biv.mau/(1-biv.mau))
    biv['logit_sup'] = np.log(biv.mau_sup/(1-biv.mau_sup))
    biv['logit_inf'] = np.log(biv.mau_inf/(1-biv.mau_inf))

    tx_mau_geral = df.mau.mean()
    woe_geral = np.log(df.mau.mean() / (1 - df.mau.mean()))

    biv['woe'] = biv.logit - woe_geral
    biv['woe_sup'] = biv.logit_sup - woe_geral
    biv['woe_inf'] = biv.logit_inf - woe_geral

    fig, ax = plt.subplots(2,1, figsize=(8,6))
    ax[0].plot(biv[var], biv.woe, ':bo', label='woe')
    ax[0].plot(biv[var], biv.woe_sup, 'o:r', label='limite superior')
    ax[0].plot(biv[var], biv.woe_inf, 'o:r', label='limite inferior')
    
    num_cat = biv.shape[0]

    ax[0].set_ylabel("Weight of Evidence")
    ax[0].legend(bbox_to_anchor=(.83, 1.17), ncol=3)
    
    ax[1] = biv.cont.plot.bar()
    return None

# %%
for var in metadados[metadados.dtype=='int64'].index:
    if (metadados.loc[var,'valores_unicos']>5):
        biv_continua(var,5,df);
    else:
        biv_continua(var,metadados.loc[var,'valores_unicos'],df);

# %%
for var in metadados[metadados.dtype=='float64'].index:
    if (metadados.loc[var,'valores_unicos']>5):
        biv_continua(var,5,df);
    else:
        biv_continua(var,metadados.loc[var,'valores_unicos'],df);

# %% [markdown]
# ## Desenvolvimento do modelo
#
# Desenvolva um modelo de *credit scoring* através de uma regressão logística.
#
# - Trate valores missings e outliers
# - Trate 'zeros estruturais'
# - Faça agrupamentos de categorias conforme vimos em aula
# - Proponha uma equação preditiva para 'mau'
# - Caso hajam categorias não significantes, justifique

# %%
df.fillna(df.tempo_emprego.mean(), inplace=True)

# %%
df.educacao.replace({'Pós graduação':'Graduação/Pós', 
                      'Superior completo':'Graduação/Pós'}, inplace=True)
biv_discreta('educacao', df)
# Out:
#                      qt_bom  qt_mau       mau             educacao    cont  \
# educacao
# Fundamental            7789     786  0.091662          Fundamental    8575
# Graduação/Pós        190437   14681  0.071573        Graduação/Pós  205118
# Médio                466106   40730  0.080361                Médio  506836
# Superior incompleto   27025    2446  0.082997  Superior incompleto   29471
#
#                            ep   mau_sup   mau_inf     logit  logit_sup  \
# educacao
# Fundamental          0.003116  0.097770  0.085554 -2.293511  -2.222252
# Graduação/Pós        0.000569  0.072689  0.070458 -2.562767  -2.546099
# Médio                0.000382  0.081110  0.079613 -2.437448  -2.427364
# Superior incompleto  0.001607  0.086147  0.079847 -2.402308  -2.361619
#
#                      logit_inf       woe   woe_sup   woe_inf
# educacao
# Fundamental          -2.369175  0.173677  0.244936  0.098013
# Graduação/Pós        -2.579677 -0.095579 -0.078911 -0.112489
# Médio                -2.447619  0.029740  0.039824  0.019570
# Superior incompleto  -2.444427  0.064880  0.105569  0.022761

# %%
' + '.join(list(metadados[metadados.index!='mau'].sort_values(by='IV', ascending=False).index))
# Out:
# 'renda + mes_ano + tempo_emprego + data_ref + mes + ano + idade + posse_de_imovel + tipo_renda + educacao + tipo_residencia + index + sexo + qt_pessoas_residencia + estado_civil + posse_de_veiculo + qtd_filhos'

# %%
formula = '''
    mau ~ renda + tempo_emprego + idade + posse_de_imovel + tipo_renda + educacao + tipo_residencia + 
          sexo + qt_pessoas_residencia + estado_civil + posse_de_veiculo + qtd_filhos
'''

rl = smf.glm(formula, data=df, family=sm.families.Binomial()).fit()

rl.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Generalized Linear Model Regression Results
# =======================================================================================
# Dep. Variable:     ['mau[False]', 'mau[True]']   No. Observations:               750000
# Model:                                     GLM   Df Residuals:                   749975
# Model Family:                         Binomial   Df Model:                           24
# Link Function:                           Logit   Scale:                          1.0000
# Method:                                   IRLS   Log-Likelihood:            -1.8357e+05
# Date:                         Tue, 18 Jul 2023   Deviance:                   3.6714e+05
# Time:                                 19:08:04   Pearson chi2:                 4.63e+16
# No. Iterations:                             11   Pseudo R-squ. (CS):            0.05742
# Covariance Type:                     nonrobust
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                            0.9779      0.159      6.166      0.000       0.667       1.289
# posse_de_imovel[T.S]                 0.0913      0.009      9.629      0.000       0.073       0.110
# tipo_renda[T.Bolsista]               0.1483      0.269      0.552      0.581      -0.378       0.675
# tipo_renda[T.Empresário]             0.0488      0.011      4.341      0.000       0.027       0.071
# tipo_renda[T.Pensionista]            0.0185      0.016      1.140      0.254      -0.013       0.050
# tipo_renda[T.Servidor público]       0.0279      0.019      1.503      0.133      -0.008       0.064
# educacao[T.Graduação/Pós]            0.1282      0.040      3.233      0.001       0.050       0.206
# educacao[T.Médio]                    0.0699      0.039      1.798      0.072      -0.006       0.146
# educacao[T.Superior incompleto]      0.1128      0.044      2.535      0.011       0.026       0.200
# tipo_residencia[T.Casa]              0.0625      0.036      1.747      0.081      -0.008       0.133
# tipo_residencia[T.Com os pais]       0.0542      0.040      1.348      0.178      -0.025       0.133
# tipo_residencia[T.Comunitário]       0.1781      0.074      2.423      0.015       0.034       0.322
# tipo_residencia[T.Estúdio]           0.0464      0.067      0.696      0.486      -0.084       0.177
# tipo_residencia[T.Governamental]     0.0429      0.043      0.996      0.319      -0.042       0.127
# sexo[T.M]                            0.1210      0.011     11.516      0.000       0.100       0.142
# estado_civil[T.Separado]             0.0060      0.076      0.079      0.937      -0.144       0.156
# estado_civil[T.Solteiro]             0.0344      0.075      0.460      0.646      -0.112       0.181
# estado_civil[T.União]               -0.0307      0.016     -1.870      0.061      -0.063       0.001
# estado_civil[T.Viúvo]                0.0841      0.078      1.084      0.278      -0.068       0.236
# posse_de_veiculo[T.S]               -0.0238      0.010     -2.397      0.017      -0.043      -0.004
# renda                                0.0001   1.05e-06    121.349      0.000       0.000       0.000
# tempo_emprego                        0.0270      0.001     19.270      0.000       0.024       0.030
# idade                                0.0002      0.001      0.434      0.664      -0.001       0.001
# qt_pessoas_residencia                0.0412      0.074      0.557      0.578      -0.104       0.186
# qtd_filhos                          -0.0424      0.074     -0.572      0.567      -0.188       0.103
# ====================================================================================================
# """

# %%
formula = '''
    mau ~ renda + tempo_emprego + posse_de_imovel + sexo
'''

rl = smf.glm(formula, data=df, family=sm.families.Binomial()).fit()

rl.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Generalized Linear Model Regression Results
# =======================================================================================
# Dep. Variable:     ['mau[False]', 'mau[True]']   No. Observations:               750000
# Model:                                     GLM   Df Residuals:                   749995
# Model Family:                         Binomial   Df Model:                            4
# Link Function:                           Logit   Scale:                          1.0000
# Method:                                   IRLS   Log-Likelihood:            -1.8361e+05
# Date:                         Tue, 18 Jul 2023   Deviance:                   3.6722e+05
# Time:                                 19:08:20   Pearson chi2:                 4.63e+16
# No. Iterations:                             11   Pseudo R-squ. (CS):            0.05732
# Covariance Type:                     nonrobust
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.2216      0.011    113.057      0.000       1.200       1.243
# posse_de_imovel[T.S]     0.0940      0.009     10.239      0.000       0.076       0.112
# sexo[T.M]                0.1058      0.010     11.022      0.000       0.087       0.125
# renda                    0.0001   1.04e-06    122.358      0.000       0.000       0.000
# tempo_emprego            0.0269      0.001     20.569      0.000       0.024       0.029
# ========================================================================================
# """

# %% [markdown]
# Chegou-se na fórmula final por meio da análise p-valor das variáveis do modelo nos seguintes passos:
# - Retirou-se idade, qt_pessoas_residencia e qtd_filhos
# - Retirou-se estado_civil
# - Retirou-se tipo_residencia
# - Retirou-se tipo_renda
# - Retirou-se educacao
# - Retirou-se posse_de_veiculo

# %% [markdown]
# ## Avaliação do modelo
#
# Avalie o poder discriminante do modelo pelo menos avaliando acurácia, KS e Gini.
#
# Avalie estas métricas nas bases de desenvolvimento e *out of time*.

# %%
df['score'] = rl.predict(df)

# Acurácia
acc = metrics.accuracy_score(df.mau, df.score>.068)
#AUC
fpr, tpr, thresholds = metrics.roc_curve(df.mau, df.score)
auc = metrics.auc(fpr, tpr)
#Gini
gini = 2*auc -1
ks = ks_2samp(df.loc[df.mau == 1, 'score'], df.loc[df.mau != 1, 'score']).statistic

print('Acurácia: {0:.1%} \nAUC: {1:.1%} \nGINI: {2:.1%}\nKS: {3:.1%}'
      .format(acc, auc, gini, ks))
# Out:
# Acurácia: 7.8%
# AUC: 22.3%
# GINI: -55.4%
# KS: 41.6%

# %%
df['ano'] = df['data_ref'].dt.year
df['mes'] = df['data_ref'].dt.month
df['mes_ano'] = df['data_ref'].dt.strftime('%m-%Y')

df_modelo = df[df['ano']==2015].copy()
df_oot = df[df['ano']==2016].copy()

# %%
df_modelo['score'] = rl.predict(df_modelo)

# Acurácia
acc = metrics.accuracy_score(df_modelo.mau, df_modelo.score>.068)
#AUC
fpr, tpr, thresholds = metrics.roc_curve(df_modelo.mau, df_modelo.score)
auc = metrics.auc(fpr, tpr)
#Gini
gini = 2*auc -1
ks = ks_2samp(df_modelo.loc[df_modelo.mau == 1, 'score'], df_modelo.loc[df_modelo.mau != 1, 'score']).statistic

print('Acurácia: {0:.1%} \nAUC: {1:.1%} \nGINI: {2:.1%}\nKS: {3:.1%}'
      .format(acc, auc, gini, ks))
# Out:
# Acurácia: 6.1%
# AUC: 23.3%
# GINI: -53.4%
# KS: 39.5%

# %%
df_oot['score'] = rl.predict(df_oot)

# Acurácia
acc = metrics.accuracy_score(df_oot.mau, df_oot.score>.068)
#AUC
fpr, tpr, thresholds = metrics.roc_curve(df_oot.mau, df_oot.score)
auc = metrics.auc(fpr, tpr)
#Gini
gini = 2*auc -1
ks = ks_2samp(df_oot.loc[df_oot.mau == 1, 'score'], df_oot.loc[df_oot.mau != 1, 'score']).statistic

print('Acurácia: {0:.1%} \nAUC: {1:.1%} \nGINI: {2:.1%}\nKS: {3:.1%}'
      .format(acc, auc, gini, ks))
# Out:
# Acurácia: 14.7%
# AUC: 27.3%
# GINI: -45.5%
# KS: 33.4%

# %% [markdown]
# ## Criar um pipeline utilizando o sklearn pipeline

# %% [markdown]
# ## Pré processamento

# %% [markdown]
# ### Substituição de nulos (nans)
#
# Existe nulos na base? é dado numérico ou categórico? qual o valor de substituição? média? valor mais frequente? etc

# %%
df_raw = pd.read_feather('credit_scoring.ftr')

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   data_ref               750000 non-null  datetime64[ns]
#  1   index                  750000 non-null  int64
#  2   sexo                   750000 non-null  object
#  3   posse_de_veiculo       750000 non-null  object
#  4   posse_de_imovel        750000 non-null  object
#  5   qtd_filhos             750000 non-null  int64
#  6   tipo_renda             750000 non-null  object
#  7   educacao               750000 non-null  object
#  8   estado_civil           750000 non-null  object
#  9   tipo_residencia        750000 non-null  object
#  10  idade                  750000 non-null  int64
#  11  tempo_emprego          624043 non-null  float64
#  12  qt_pessoas_residencia  750000 non-null  float64
#  13  renda                  750000 non-null  float64
#  14  mau                    750000 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(3), int64(3), object(7)
# memory usage: 80.8+ MB

# %%
df_raw.fillna(df_raw.tempo_emprego.mean(), inplace=True)

# %% [markdown]
# Opta-se por preencher os missings pela média da variável, devido à alta quantidade de informação que poderia ser perdida caso as linhas fossem excluídas da base.

# %% [markdown]
# ### Remoção de outliers
#
# Como identificar outlier? Substituir o outlier por algum valor? Remover a linha?

# %%
df_raw.describe()
# Out:
#                index     qtd_filhos          idade  tempo_emprego  \
# count  750000.000000  750000.000000  750000.000000  750000.000000
# mean     8319.272793       0.433251      43.804733       7.748574
# std      4809.281774       0.739379      11.229868       6.100107
# min         0.000000       0.000000      22.000000       0.117808
# 25%      4147.000000       0.000000      34.000000       3.635616
# 50%      8324.000000       0.000000      43.000000       7.473973
# 75%     12487.000000       1.000000      53.000000       9.090411
# max     16649.000000      14.000000      68.000000      42.906849
#
#        qt_pessoas_residencia         renda
# count          750000.000000  7.500000e+05
# mean                2.212241  2.323854e+04
# std                 0.903428  7.910601e+04
# min                 1.000000  1.076700e+02
# 25%                 2.000000  3.467700e+03
# 50%                 2.000000  7.861820e+03
# 75%                 3.000000  1.831828e+04
# max                15.000000  4.083986e+06

# %%
df_raw.qtd_filhos.value_counts()
# Out:
# 0     517331
# 1     153021
# 2      69632
# 3       8669
# 4       1065
# 7        101
# 5         95
# 14        86
# Name: qtd_filhos, dtype: int64

# %%
df_raw.qt_pessoas_residencia.value_counts()
# Out:
# 2.0     407776
# 1.0     135768
# 3.0     130068
# 4.0      66759
# 5.0       8282
# 6.0       1108
# 9.0        101
# 15.0        86
# 7.0         52
# Name: qt_pessoas_residencia, dtype: int64

# %%
df_raw = df_raw[df_raw['qtd_filhos']<7]

# %% [markdown]
# Opta-se por retirar as linhas cujos dados são discrepantes em virtude da baixa representatividade frente às demais.

# %% [markdown]
# ### Seleção de variáveis
#
# Qual tipo de técnica? Boruta? Feature importance?

# %%
formula = '''
    mau ~ renda + tempo_emprego + idade + posse_de_imovel + tipo_renda + educacao + tipo_residencia + 
          sexo + qt_pessoas_residencia + estado_civil + posse_de_veiculo + qtd_filhos
'''

rl = smf.glm(formula, data=df_raw, family=sm.families.Binomial()).fit()

rl.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Generalized Linear Model Regression Results
# =======================================================================================
# Dep. Variable:     ['mau[False]', 'mau[True]']   No. Observations:               749813
# Model:                                     GLM   Df Residuals:                   749787
# Model Family:                         Binomial   Df Model:                           25
# Link Function:                           Logit   Scale:                          1.0000
# Method:                                   IRLS   Log-Likelihood:            -1.8349e+05
# Date:                         Tue, 18 Jul 2023   Deviance:                   3.6698e+05
# Time:                                 19:09:44   Pearson chi2:                 4.63e+16
# No. Iterations:                             11   Pseudo R-squ. (CS):            0.05740
# Covariance Type:                     nonrobust
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                            0.9727      0.159      6.129      0.000       0.662       1.284
# posse_de_imovel[T.S]                 0.0909      0.009      9.585      0.000       0.072       0.110
# tipo_renda[T.Bolsista]               0.1500      0.269      0.559      0.576      -0.376       0.677
# tipo_renda[T.Empresário]             0.0487      0.011      4.330      0.000       0.027       0.071
# tipo_renda[T.Pensionista]            0.0185      0.016      1.144      0.253      -0.013       0.050
# tipo_renda[T.Servidor público]       0.0280      0.019      1.507      0.132      -0.008       0.064
# educacao[T.Médio]                    0.0697      0.039      1.793      0.073      -0.006       0.146
# educacao[T.Pós graduação]            0.2609      0.143      1.821      0.069      -0.020       0.542
# educacao[T.Superior completo]        0.1273      0.040      3.210      0.001       0.050       0.205
# educacao[T.Superior incompleto]      0.1126      0.044      2.532      0.011       0.025       0.200
# tipo_residencia[T.Casa]              0.0624      0.036      1.744      0.081      -0.008       0.132
# tipo_residencia[T.Com os pais]       0.0543      0.040      1.350      0.177      -0.025       0.133
# tipo_residencia[T.Comunitário]       0.1783      0.074      2.426      0.015       0.034       0.322
# tipo_residencia[T.Estúdio]           0.0456      0.067      0.683      0.494      -0.085       0.176
# tipo_residencia[T.Governamental]     0.0428      0.043      0.993      0.321      -0.042       0.127
# sexo[T.M]                            0.1213      0.011     11.540      0.000       0.101       0.142
# estado_civil[T.Separado]             0.0085      0.076      0.111      0.911      -0.141       0.158
# estado_civil[T.Solteiro]             0.0363      0.075      0.485      0.628      -0.110       0.183
# estado_civil[T.União]               -0.0303      0.016     -1.842      0.065      -0.062       0.002
# estado_civil[T.Viúvo]                0.0854      0.078      1.099      0.272      -0.067       0.238
# posse_de_veiculo[T.S]               -0.0240      0.010     -2.416      0.016      -0.044      -0.005
# renda                                0.0001   1.05e-06    121.314      0.000       0.000       0.000
# tempo_emprego                        0.0270      0.001     19.280      0.000       0.024       0.030
# idade                                0.0003      0.001      0.550      0.583      -0.001       0.001
# qt_pessoas_residencia                0.0419      0.074      0.567      0.571      -0.103       0.187
# qtd_filhos                          -0.0402      0.074     -0.542      0.588      -0.186       0.105
# ====================================================================================================
# """

# %%
formula = '''
    mau ~ renda + tempo_emprego + posse_de_imovel + sexo
'''

rl = smf.glm(formula, data=df_raw, family=sm.families.Binomial()).fit()

rl.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Generalized Linear Model Regression Results
# =======================================================================================
# Dep. Variable:     ['mau[False]', 'mau[True]']   No. Observations:               749813
# Model:                                     GLM   Df Residuals:                   749808
# Model Family:                         Binomial   Df Model:                            4
# Link Function:                           Logit   Scale:                          1.0000
# Method:                                   IRLS   Log-Likelihood:            -1.8353e+05
# Date:                         Tue, 18 Jul 2023   Deviance:                   3.6706e+05
# Time:                                 19:10:01   Pearson chi2:                 4.63e+16
# No. Iterations:                             11   Pseudo R-squ. (CS):            0.05730
# Covariance Type:                     nonrobust
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.2218      0.011    113.034      0.000       1.201       1.243
# posse_de_imovel[T.S]     0.0941      0.009     10.243      0.000       0.076       0.112
# sexo[T.M]                0.1061      0.010     11.046      0.000       0.087       0.125
# renda                    0.0001   1.04e-06    122.318      0.000       0.000       0.000
# tempo_emprego            0.0269      0.001     20.577      0.000       0.024       0.029
# ========================================================================================
# """

# %% [markdown]
# Faz a seleção das variáveis por meio da análise de p-valor oriunda do modelo de regressão aplicado.

# %% [markdown]
# ### Redução de dimensionalidade (PCA)
#
# Aplicar PCA para reduzir a dimensionalidade para 5

# %%
df_raw_y = df_raw[['mau']]
df_raw_x = df_raw[['renda','tempo_emprego','posse_de_imovel','sexo']].copy()
df_raw_x['posse_de_imovel'].replace(['N','S'],[0,1], inplace=True)
df_raw_x['sexo'].replace(['F','M'],[0,1], inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_raw_x, df_raw_y, test_size=0.3, random_state=10)

# %%
pca = PCA(n_components=4)
scaler = StandardScaler()
logistic = LogisticRegression(max_iter=200)

# %%
scaler.fit(X_train)
X_train = scaler.transform(X_train)
pca.fit(X_train)
X_train = pca.transform(X_train)
logistic.fit(X_train, y_train)
logistic.predict(X_train)

X_test = scaler.transform(X_test)
X_test = pca.transform(X_test)
logistic.predict(X_test)
# Out:
# array([False, False, False, ..., False, False, False])

# %% [markdown]
# ### Criação de dummies
#
# Aplicar o get_dummies() ou onehotencoder() para transformar colunas catégoricas do dataframe em colunas de 0 e 1.
# - sexo
# - posse_de_veiculo
# - posse_de_imovel
# - tipo_renda
# - educacao
# - estado_civil
# - tipo_residencia

# %% [markdown]
# Ação já executada na etapa anterior.

# %% [markdown]
# ### Pipeline
#
# Crie um pipeline contendo essas funções.
#
# preprocessamento()
# - substituicao de nulos
# - remoção outliers
# - PCA
# - Criação de dummy de pelo menos 1 variável (posse_de_veiculo)

# %%
def substitui_null(df: pd.DataFrame, var: str) -> pd.DataFrame:
    df.fillna(df[var].mean(), inplace=True)

def remove_outlier(df: pd.DataFrame, var: str, criterio: int) -> pd.DataFrame:
    df = df[df[var]<criterio]

def cria_dummy(df: pd.DataFrame, var: str) -> pd.DataFrame:
    pd.get_dummies(df.var)

# %%
substitui_pipe = substitui_null(df_raw, 'tempo_emprego')
remove_pipe = remove_outlier(df_raw, 'qtd_filhos', 7)
pca_pipe = PCA(n_components=4)
dummy_pipe = cria_dummy(df_raw, 'posse_de_imovel')

pipe = Pipeline(steps=[("substitui_null", substitui_pipe),
                       ("remove_outlier", remove_pipe), 
                       ("pca", pca_pipe),
                       ("cria_dummy", dummy_pipe)])

# %% [markdown]
# ### Treinar um modelo de regressão logística com o resultado

# %%
model = logistic.fit(X_train, y_train)

# %% [markdown]
# ### Salvar o pickle file do modelo treinado

# %%
nome_arquivo = 'model_final.pkl'
pickle.dump(model, open(nome_arquivo, 'wb'))

# %% [markdown]
# ## Pycaret na base de dados
#
# Utilize o pycaret para pre processar os dados e rodar o modelo **lightgbm**. Faça todos os passos a passos da aula e gere os gráficos finais. E o pipeline de toda a transformação.

# %%
df = pd.read_feather('credit_scoring.ftr')

# %%
exp_clf101 = setup(data = df, target = 'mau', session_id=123)
# Out:
# <style type="text/css">
# #T_9d9b4_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9d9b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d9b4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9d9b4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d9b4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d9b4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9d9b4_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9d9b4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9d9b4_row1_col1" class="data row1 col1" >mau</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9d9b4_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9d9b4_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9d9b4_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_9d9b4_row3_col1" class="data row3 col1" >(750000, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9d9b4_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_9d9b4_row4_col1" class="data row4 col1" >(750000, 34)</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9d9b4_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_9d9b4_row5_col1" class="data row5 col1" >(525000, 34)</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9d9b4_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_9d9b4_row6_col1" class="data row6 col1" >(225000, 34)</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9d9b4_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_9d9b4_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9d9b4_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_9d9b4_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9d9b4_row9_col0" class="data row9 col0" >Date features</td>
#       <td id="T_9d9b4_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9d9b4_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_9d9b4_row10_col1" class="data row10 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9d9b4_row11_col0" class="data row11 col0" >Rows with missing values</td>
#       <td id="T_9d9b4_row11_col1" class="data row11 col1" >16.8%</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9d9b4_row12_col0" class="data row12 col0" >Preprocess</td>
#       <td id="T_9d9b4_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9d9b4_row13_col0" class="data row13 col0" >Imputation type</td>
#       <td id="T_9d9b4_row13_col1" class="data row13 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9d9b4_row14_col0" class="data row14 col0" >Numeric imputation</td>
#       <td id="T_9d9b4_row14_col1" class="data row14 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9d9b4_row15_col0" class="data row15 col0" >Categorical imputation</td>
#       <td id="T_9d9b4_row15_col1" class="data row15 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9d9b4_row16_col0" class="data row16 col0" >Maximum one-hot encoding</td>
#       <td id="T_9d9b4_row16_col1" class="data row16 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9d9b4_row17_col0" class="data row17 col0" >Encoding method</td>
#       <td id="T_9d9b4_row17_col1" class="data row17 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9d9b4_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_9d9b4_row18_col1" class="data row18 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9d9b4_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_9d9b4_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_9d9b4_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_9d9b4_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_9d9b4_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_9d9b4_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_9d9b4_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_9d9b4_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_9d9b4_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_9d9b4_row23_col1" class="data row23 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b4_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_9d9b4_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_9d9b4_row24_col1" class="data row24 col1" >91d5</td>
#     </tr>
#   </tbody>
# </table>

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# dt             sklearn.tree._classes.DecisionTreeClassifier   True
# svm       sklearn.linear_model._stochastic_gradient.SGDC...   True
# rbfsvm                             sklearn.svm._classes.SVC  False
# gpc       sklearn.gaussian_process._gpc.GaussianProcessC...  False
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# ridge           sklearn.linear_model._ridge.RidgeClassifier   True
# rf          sklearn.ensemble._forest.RandomForestClassifier   True
# qda       sklearn.discriminant_analysis.QuadraticDiscrim...   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostClas...   True
# gbc         sklearn.ensemble._gb.GradientBoostingClassifier   True
# lda       sklearn.discriminant_analysis.LinearDiscrimina...   True
# et            sklearn.ensemble._forest.ExtraTreesClassifier   True
# xgboost                       xgboost.sklearn.XGBClassifier   True
# lightgbm                    lightgbm.sklearn.LGBMClassifier   True
# dummy                         sklearn.dummy.DummyClassifier   True

# %%
lightgbm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_5a102_row10_col0, #T_5a102_row10_col1, #T_5a102_row10_col2, #T_5a102_row10_col3, #T_5a102_row10_col4, #T_5a102_row10_col5, #T_5a102_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5a102">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a102_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5a102_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5a102_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5a102_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5a102_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5a102_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5a102_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a102_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a102_row0_col0" class="data row0 col0" >0.9220</td>
#       <td id="T_5a102_row0_col1" class="data row0 col1" >0.7706</td>
#       <td id="T_5a102_row0_col2" class="data row0 col2" >0.0248</td>
#       <td id="T_5a102_row0_col3" class="data row0 col3" >0.5231</td>
#       <td id="T_5a102_row0_col4" class="data row0 col4" >0.0474</td>
#       <td id="T_5a102_row0_col5" class="data row0 col5" >0.0406</td>
#       <td id="T_5a102_row0_col6" class="data row0 col6" >0.1012</td>
#     </tr>
#     <tr>
#       <th id="T_5a102_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5a102_row1_col0" class="data row1 col0" >0.9222</td>
#       <td id="T_5a102_row1_col1" class="data row1 col1" >0.7879</td>
#       <td id="T_5a102_row1_col2" class="data row1 col2" >0.0292</td>
#       <td id="T_5a102_row1_col3" class="data row1 col3" >0.5479</td>
#       <td id="T_5a102_row1_col4" class="data row1 col4" >0.0555</td>
#       <td id="T_5a102_row1_col5" class="data row1 col5" >0.0480</td>
#       <td id="T_5a102_row1_col6" class="data row1 col6" >0.1132</td>
#     </tr>
#     <tr>
#       <th id="T_5a102_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5a102_row2_col0" class="data row2 col0" >0.9223</td>
#       <td id="T_5a102_row2_col1" class="data row2 col1" >0.7796</td>
#       <td id="T_5a102_row2_col2" class="data row2 col2" >0.0270</td>
#       <td id="T_5a102_row2_col3" class="data row2 col3" >0.5722</td>
#       <td id="T_5a102_row2_col4" class="data row2 col4" >0.0516</td>
#       <td id="T_5a102_row2_col5" class="data row2 col5" >0.0449</td>
#       <td id="T_5a102_row2_col6" class="data row2 col6" >0.1121</td>
#     </tr>
#     <tr>
#       <th id="T_5a102_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5a102_row3_col0" class="data row3 col0" >0.9222</td>
#       <td id="T_5a102_row3_col1" class="data row3 col1" >0.7817</td>
#       <td id="T_5a102_row3_col2" class="data row3 col2" >0.0258</td>
#       <td id="T_5a102_row3_col3" class="data row3 col3" >0.5550</td>
#       <td id="T_5a102_row3_col4" class="data row3 col4" >0.0493</td>
#       <td id="T_5a102_row3_col5" class="data row3 col5" >0.0427</td>
#       <td id="T_5a102_row3_col6" class="data row3 col6" >0.1073</td>
#     </tr>
#     <tr>
#       <th id="T_5a102_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5a102_row4_col0" class="data row4 col0" >0.9219</td>
#       <td id="T_5a102_row4_col1" class="data row4 col1" >0.7838</td>
#       <td id="T_5a102_row4_col2" class="data row4 col2" >0.0236</td>
#       <td id="T_5a102_row4_col3" class="data row4 col3" >0.5105</td>
#       <td id="T_5a102_row4_col4" class="data row4 col4" >0.0452</td>
#       <td id="T_5a102_row4_col5" class="data row4 col5" >0.0385</td>
#       <td id="T_5a102_row4_col6" class="data row4 col6" >0.0971</td>
#     </tr>
#     <tr>
#       <th id="T_5a102_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5a102_row5_col0" class="data row5 col0" >0.9227</td>
#       <td id="T_5a102_row5_col1" class="data row5 col1" >0.7768</td>
#       <td id="T_5a102_row5_col2" class="data row5 col2" >0.0295</td>
#       <td id="T_5a102_row5_col3" class="data row5 col3" >0.6142</td>
#       <td id="T_5a102_row5_col4" class="data row5 col4" >0.0563</td>
#       <td id="T_5a102_row5_col5" class="data row5 col5" >0.0494</td>
#       <td id="T_5a102_row5_col6" class="data row5 col6" >0.1225</td>
#     </tr>
#     <tr>
#       <th id="T_5a102_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5a102_row6_col0" class="data row6 col0" >0.9226</td>
#       <td id="T_5a102_row6_col1" class="data row6 col1" >0.7830</td>
#       <td id="T_5a102_row6_col2" class="data row6 col2" >0.0287</td>
#       <td id="T_5a102_row6_col3" class="data row6 col3" >0.6020</td>
#       <td id="T_5a102_row6_col4" class="data row6 col4" >0.0549</td>
#       <td id="T_5a102_row6_col5" class="data row6 col5" >0.0481</td>
#       <td id="T_5a102_row6_col6" class="data row6 col6" >0.1194</td>
#     </tr>
#     <tr>
#       <th id="T_5a102_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5a102_row7_col0" class="data row7 col0" >0.9217</td>
#       <td id="T_5a102_row7_col1" class="data row7 col1" >0.7790</td>
#       <td id="T_5a102_row7_col2" class="data row7 col2" >0.0256</td>
#       <td id="T_5a102_row7_col3" class="data row7 col3" >0.4861</td>
#       <td id="T_5a102_row7_col4" class="data row7 col4" >0.0486</td>
#       <td id="T_5a102_row7_col5" class="data row7 col5" >0.0411</td>
#       <td id="T_5a102_row7_col6" class="data row7 col6" >0.0977</td>
#     </tr>
#     <tr>
#       <th id="T_5a102_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5a102_row8_col0" class="data row8 col0" >0.9220</td>
#       <td id="T_5a102_row8_col1" class="data row8 col1" >0.7792</td>
#       <td id="T_5a102_row8_col2" class="data row8 col2" >0.0263</td>
#       <td id="T_5a102_row8_col3" class="data row8 col3" >0.5217</td>
#       <td id="T_5a102_row8_col4" class="data row8 col4" >0.0501</td>
#       <td id="T_5a102_row8_col5" class="data row8 col5" >0.0429</td>
#       <td id="T_5a102_row8_col6" class="data row8 col6" >0.1039</td>
#     </tr>
#     <tr>
#       <th id="T_5a102_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5a102_row9_col0" class="data row9 col0" >0.9220</td>
#       <td id="T_5a102_row9_col1" class="data row9 col1" >0.7797</td>
#       <td id="T_5a102_row9_col2" class="data row9 col2" >0.0236</td>
#       <td id="T_5a102_row9_col3" class="data row9 col3" >0.5272</td>
#       <td id="T_5a102_row9_col4" class="data row9 col4" >0.0452</td>
#       <td id="T_5a102_row9_col5" class="data row9 col5" >0.0388</td>
#       <td id="T_5a102_row9_col6" class="data row9 col6" >0.0992</td>
#     </tr>
#     <tr>
#       <th id="T_5a102_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_5a102_row10_col0" class="data row10 col0" >0.9222</td>
#       <td id="T_5a102_row10_col1" class="data row10 col1" >0.7801</td>
#       <td id="T_5a102_row10_col2" class="data row10 col2" >0.0264</td>
#       <td id="T_5a102_row10_col3" class="data row10 col3" >0.5460</td>
#       <td id="T_5a102_row10_col4" class="data row10 col4" >0.0504</td>
#       <td id="T_5a102_row10_col5" class="data row10 col5" >0.0435</td>
#       <td id="T_5a102_row10_col6" class="data row10 col6" >0.1074</td>
#     </tr>
#     <tr>
#       <th id="T_5a102_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_5a102_row11_col0" class="data row11 col0" >0.0003</td>
#       <td id="T_5a102_row11_col1" class="data row11 col1" >0.0043</td>
#       <td id="T_5a102_row11_col2" class="data row11 col2" >0.0021</td>
#       <td id="T_5a102_row11_col3" class="data row11 col3" >0.0386</td>
#       <td id="T_5a102_row11_col4
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
tuned_lightgbm = tune_model(lightgbm, optimize='F1')
# Out:
# <style type="text/css">
# #T_1136d_row10_col0, #T_1136d_row10_col1, #T_1136d_row10_col2, #T_1136d_row10_col3, #T_1136d_row10_col4, #T_1136d_row10_col5, #T_1136d_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1136d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1136d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_1136d_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_1136d_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_1136d_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_1136d_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_1136d_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_1136d_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1136d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1136d_row0_col0" class="data row0 col0" >0.9194</td>
#       <td id="T_1136d_row0_col1" class="data row0 col1" >0.7619</td>
#       <td id="T_1136d_row0_col2" class="data row0 col2" >0.0285</td>
#       <td id="T_1136d_row0_col3" class="data row0 col3" >0.3241</td>
#       <td id="T_1136d_row0_col4" class="data row0 col4" >0.0524</td>
#       <td id="T_1136d_row0_col5" class="data row0 col5" >0.0403</td>
#       <td id="T_1136d_row0_col6" class="data row0 col6" >0.0762</td>
#     </tr>
#     <tr>
#       <th id="T_1136d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1136d_row1_col0" class="data row1 col0" >0.9201</td>
#       <td id="T_1136d_row1_col1" class="data row1 col1" >0.7784</td>
#       <td id="T_1136d_row1_col2" class="data row1 col2" >0.0380</td>
#       <td id="T_1136d_row1_col3" class="data row1 col3" >0.3871</td>
#       <td id="T_1136d_row1_col4" class="data row1 col4" >0.0692</td>
#       <td id="T_1136d_row1_col5" class="data row1 col5" >0.0560</td>
#       <td id="T_1136d_row1_col6" class="data row1 col6" >0.1012</td>
#     </tr>
#     <tr>
#       <th id="T_1136d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1136d_row2_col0" class="data row2 col0" >0.9192</td>
#       <td id="T_1136d_row2_col1" class="data row2 col1" >0.7687</td>
#       <td id="T_1136d_row2_col2" class="data row2 col2" >0.0312</td>
#       <td id="T_1136d_row2_col3" class="data row2 col3" >0.3274</td>
#       <td id="T_1136d_row2_col4" class="data row2 col4" >0.0569</td>
#       <td id="T_1136d_row2_col5" class="data row2 col5" >0.0439</td>
#       <td id="T_1136d_row2_col6" class="data row2 col6" >0.0804</td>
#     </tr>
#     <tr>
#       <th id="T_1136d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1136d_row3_col0" class="data row3 col0" >0.9198</td>
#       <td id="T_1136d_row3_col1" class="data row3 col1" >0.7723</td>
#       <td id="T_1136d_row3_col2" class="data row3 col2" >0.0305</td>
#       <td id="T_1136d_row3_col3" class="data row3 col3" >0.3511</td>
#       <td id="T_1136d_row3_col4" class="data row3 col4" >0.0560</td>
#       <td id="T_1136d_row3_col5" class="data row3 col5" >0.0441</td>
#       <td id="T_1136d_row3_col6" class="data row3 col6" >0.0840</td>
#     </tr>
#     <tr>
#       <th id="T_1136d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1136d_row4_col0" class="data row4 col0" >0.9195</td>
#       <td id="T_1136d_row4_col1" class="data row4 col1" >0.7734</td>
#       <td id="T_1136d_row4_col2" class="data row4 col2" >0.0331</td>
#       <td id="T_1136d_row4_col3" class="data row4 col3" >0.3452</td>
#       <td id="T_1136d_row4_col4" class="data row4 col4" >0.0605</td>
#       <td id="T_1136d_row4_col5" class="data row4 col5" >0.0474</td>
#       <td id="T_1136d_row4_col6" class="data row4 col6" >0.0865</td>
#     </tr>
#     <tr>
#       <th id="T_1136d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1136d_row5_col0" class="data row5 col0" >0.9202</td>
#       <td id="T_1136d_row5_col1" class="data row5 col1" >0.7671</td>
#       <td id="T_1136d_row5_col2" class="data row5 col2" >0.0353</td>
#       <td id="T_1136d_row5_col3" class="data row5 col3" >0.3846</td>
#       <td id="T_1136d_row5_col4" class="data row5 col4" >0.0647</td>
#       <td id="T_1136d_row5_col5" class="data row5 col5" >0.0522</td>
#       <td id="T_1136d_row5_col6" class="data row5 col6" >0.0971</td>
#     </tr>
#     <tr>
#       <th id="T_1136d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1136d_row6_col0" class="data row6 col0" >0.9196</td>
#       <td id="T_1136d_row6_col1" class="data row6 col1" >0.7728</td>
#       <td id="T_1136d_row6_col2" class="data row6 col2" >0.0312</td>
#       <td id="T_1136d_row6_col3" class="data row6 col3" >0.3422</td>
#       <td id="T_1136d_row6_col4" class="data row6 col4" >0.0572</td>
#       <td id="T_1136d_row6_col5" class="data row6 col5" >0.0447</td>
#       <td id="T_1136d_row6_col6" class="data row6 col6" >0.0833</td>
#     </tr>
#     <tr>
#       <th id="T_1136d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1136d_row7_col0" class="data row7 col0" >0.9200</td>
#       <td id="T_1136d_row7_col1" class="data row7 col1" >0.7697</td>
#       <td id="T_1136d_row7_col2" class="data row7 col2" >0.0341</td>
#       <td id="T_1136d_row7_col3" class="data row7 col3" >0.3714</td>
#       <td id="T_1136d_row7_col4" class="data row7 col4" >0.0625</td>
#       <td id="T_1136d_row7_col5" class="data row7 col5" >0.0500</td>
#       <td id="T_1136d_row7_col6" class="data row7 col6" >0.0929</td>
#     </tr>
#     <tr>
#       <th id="T_1136d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1136d_row8_col0" class="data row8 col0" >0.9190</td>
#       <td id="T_1136d_row8_col1" class="data row8 col1" >0.7674</td>
#       <td id="T_1136d_row8_col2" class="data row8 col2" >0.0273</td>
#       <td id="T_1136d_row8_col3" class="data row8 col3" >0.3027</td>
#       <td id="T_1136d_row8_col4" class="data row8 col4" >0.0501</td>
#       <td id="T_1136d_row8_col5" class="data row8 col5" >0.0376</td>
#       <td id="T_1136d_row8_col6" class="data row8 col6" >0.0705</td>
#     </tr>
#     <tr>
#       <th id="T_1136d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1136d_row9_col0" class="data row9 col0" >0.9194</td>
#       <td id="T_1136d_row9_col1" class="data row9 col1" >0.7714</td>
#       <td id="T_1136d_row9_col2" class="data row9 col2" >0.0331</td>
#       <td id="T_1136d_row9_col3" class="data row9 col3" >0.3400</td>
#       <td id="T_1136d_row9_col4" class="data row9 col4" >0.0604</td>
#       <td id="T_1136d_row9_col5" class="data row9 col5" >0.0471</td>
#       <td id="T_1136d_row9_col6" class="data row9 col6" >0.0854</td>
#     </tr>
#     <tr>
#       <th id="T_1136d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_1136d_row10_col0" class="data row10 col0" >0.9196</td>
#       <td id="T_1136d_row10_col1" class="data row10 col1" >0.7703</td>
#       <td id="T_1136d_row10_col2" class="data row10 col2" >0.0322</td>
#       <td id="T_1136d_row10_col3" class="data row10 col3" >0.3476</td>
#       <td id="T_1136d_row10_col4" class="data row10 col4" >0.0590</td>
#       <td id="T_1136d_row10_col5" class="data row10 col5" >0.0463</td>
#       <td id="T_1136d_row10_col6" class="data row10 col6" >0.0857</td>
#     </tr>
#     <tr>
#       <th id="T_1136d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_1136d_row11_col0" class="data row11 col0" >0.0004</td>
#       <td id="T_1136d_row11_col1" class="data row11 col1" >0.0042</td>
#       <td id="T_1136d_row11_col2" class="data row11 col2" >0.0030</td>
#       <td id="T_1136d_row11_col3" class="data row11 col3" >0.0256</td>
#       <td id="T_1136d_row11_col4
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
plot_model(tuned_lightgbm, plot = 'auc')

# %%
plot_model(tuned_lightgbm, plot = 'pr')

# %%
plot_model(tuned_lightgbm, plot='feature')

# %%
plot_model(tuned_lightgbm, plot = 'confusion_matrix')

# %%
predict_model(tuned_lightgbm);
# Out:
# <style type="text/css">
# </style>
# <table id="T_25bad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25bad_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_25bad_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_25bad_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_25bad_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_25bad_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_25bad_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_25bad_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_25bad_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25bad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_25bad_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_25bad_row0_col1" class="data row0 col1" >0.9199</td>
#       <td id="T_25bad_row0_col2" class="data row0 col2" >0.7730</td>
#       <td id="T_25bad_row0_col3" class="data row0 col3" >0.0320</td>
#       <td id="T_25bad_row0_col4" class="data row0 col4" >0.3609</td>
#       <td id="T_25bad_row0_col5" class="data row0 col5" >0.0588</td>
#       <td id="T_25bad_row0_col6" class="data row0 col6" >0.0466</td>
#       <td id="T_25bad_row0_col7" class="data row0 col7" >0.0880</td>
#     </tr>
#   </tbody>
# </table>

# %%
final_lightgbm = finalize_model(tuned_lightgbm)

# %%
predict_model(final_lightgbm);
# Out:
# <style type="text/css">
# </style>
# <table id="T_7ff8e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ff8e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7ff8e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7ff8e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7ff8e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7ff8e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7ff8e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7ff8e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7ff8e_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ff8e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7ff8e_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_7ff8e_row0_col1" class="data row0 col1" >0.9221</td>
#       <td id="T_7ff8e_row0_col2" class="data row0 col2" >0.7963</td>
#       <td id="T_7ff8e_row0_col3" class="data row0 col3" >0.0380</td>
#       <td id="T_7ff8e_row0_col4" class="data row0 col4" >0.5222</td>
#       <td id="T_7ff8e_row0_col5" class="data row0 col5" >0.0709</td>
#       <td id="T_7ff8e_row0_col6" class="data row0 col6" >0.0609</td>
#       <td id="T_7ff8e_row0_col7" class="data row0 col7" >0.1252</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Salvar o arquivo do modelo treinado

# %%
save_model(final_lightgbm,'Final GBC Model 28Apr2023')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\Acer\AppData\Local\Temp\joblib),
#           steps=[('date_feature_extractor',
#                   TransformerWrapper(exclude=None, include=['data_ref'],
#                                      transformer=ExtractDateTimeFeatures(features=['day',
#                                                                                    'month',
#                                                                                    'year']))),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['index', 'qtd_filhos', 'idade',
#                                               'tempo_emprego',
#                                               'qt_pesso...
#                                  colsample_bytree=1.0, feature_fraction=0.5,
#                                  importance_type='split', learning_rate=0.4,
#                                  max_depth=-1, min_child_samples=6,
#                                  min_child_weight=0.001, min_split_gain=0.3,
#                                  n_estimators=20, n_jobs=-1, num_leaves=150,
#                                  objective=None, random_state=123,
#                                  reg_alpha=0.005, reg_lambda=0.0005,
#                                  silent='warn', subsample=1.0,
#                                  subsample_for_bin=200000, subsample_freq=0))],
#           verbose=False),
#  'Final GBC Model 28Apr2023.pkl')

# %%
finalize_pipe = finalize_model(tuned_lightgbm)
predict_pipe = predict_model(final_lightgbm)
save_pipe = save_model(final_lightgbm,'Final GBC Model 28Apr2023')

pipe = Pipeline(steps=[("finalize", finalize_pipe),
                       ("predict", predict_pipe),
                       ("save", save_pipe)])

# %% [markdown]
# # Projeto Final
#
# 1. Subir no GITHUB todos os jupyter notebooks/códigos que você desenvolveu nesse ultimo módulo: **DONE**
# 1. Gerar um arquivo python (.py) com todas as funções necessárias para rodar no streamlit a escoragem do arquivo de treino
#     - Criar um .py
#     - Criar um carregador de csv no streamlit
#     - Subir um csv no streamlit
#     - Criar um pipeline de pré processamento dos dados
#     - Utilizar o modelo treinado para escorar a base
#         - nome_arquivo = 'model_final.pkl'
# 1. Gravar um vídeo da tela do streamlit em funcionamento (usando o próprio streamlit (temos aula disso) ou qlqr outra forma de gravação).
# 1. Subir no Github o vídeo de funcionamento da ferramenta como README.md.
# 1. Subir no Github os códigos desenvolvidos.
# 1. Enviar links do github para o tutor corrigir.
